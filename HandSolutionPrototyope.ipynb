# %% [markdown]
# # Solution to the M13 puzzle by hand.
#
# Taken from : Jacob A. Siehler (2011) Depth and Symmetry in Conway's M13 Puzzle,
# Mathematics Magazine, 84:4, 243-256, DOI: 10.4169/math.mag.84.4.243
#
# - First step: translate Siehler's

# %%
from permutation import *
 
# translating between my coordinate system and the one used by the puzzle
lines = []
lines.append((1,6,8,10))
lines.append((1,2,3,0))
lines.append((1,5,9, 12))
lines.append((1,4,7,11))
lines.append((2,5,8,11))
lines.append((3,5,7,10))
lines.append((3,6,9,11))
lines.append((4,5,6,0))
lines.append((7,8,9,0))
lines.append((9,2,4,10))
lines.append((10,11,12,0))
lines.append((3,4,8,12))
lines.append((7,2,6,12))

lines_siehler = []
for i in range(13):
    lines_siehler.append([i, (i+1)%13, (i+5)%13, (i-2)%13])

# find a permutation that preserves the lines
# and maps node 0 to node 0
# and maps 1 to 1
# with a bit of brute force, we find that the following works:
mapping = permutation([0,1,5,11,2,7,3,6,8,9,4,12,10])

# %%
# Out:
# [[0, 1, 5, 11],
#  [1, 2, 6, 12],
#  [2, 3, 7, 0],
#  [3, 4, 8, 1],
#  [4, 5, 9, 2],
#  [5, 6, 10, 3],
#  [6, 7, 11, 4],
#  [7, 8, 12, 5],
#  [8, 9, 0, 6],
#  [9, 10, 1, 7],
#  [10, 11, 2, 8],
#  [11, 12, 3, 9],
#  [12, 0, 4, 10]]
